# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 最优化
# * 很多的机器学习算法都是没有解析解的，也就是无法正常解的，所以就有一个学科叫最优化理论
# * 这里的损失函数最优化采用梯度下降法

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 正则化
# * 假如选民的素质不高，就容易受某些因素的影响很大，所以我们应该找出那些因素有问题，并对它进行限制
# * 在找损失函数最优化时，我们会给损失函数加一个值，这个值不是常量，会因为计算$W$的不同影响不一样，也就是对得到的$W$进行了限制，而不是完全信任$W$
# * 加这个项就是正则化，而就是让特征向量的权重$W$更加准确（下一章会具体介绍）
# * 有三种正则项的算法，L1 & L2 & 弹性网络（L1+L2）

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
